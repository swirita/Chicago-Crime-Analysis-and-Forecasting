# %% [markdown]
# <a href="https://colab.research.google.com/github/swirita/Chicago-Crime-Analysis-and-Forecasting/blob/main/Chicago_Crime_Analysis_and_Forecasting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chicago Crime Analysis & Forecasting
#
# - Author: Siwar Ehwass

# %% [markdown]
# ## Overview

# %% [markdown]
# ## Imports

# %% [markdown]
# ## Load & Inspect Data

# %% [markdown]
# ## Data Cleaning & Feature Inspection

# %% [markdown]
# ## EDA

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ## Evaluation
